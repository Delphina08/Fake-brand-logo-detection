# %% [markdown]
# ## Model with same dropout rate(0.5) for dropout layers.

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
initializer = tf.keras.initializers.HeUniform()

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding="same", input_shape=(256, 256, 1)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer=initializer, padding="same"))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_initializer=initializer))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Dense(2, activation='softmax'))

model.summary()
model.compile(optimizer='RMSprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model for 20 epochs with a batch size of 25
history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(val_images, val_labels), batch_size=25, verbose=1)

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_images, test_labels)

# Evaluate the model on validation data
validation_loss, validation_acc = model.evaluate(val_images, val_labels)

# Print the test and validation accuracy
print('Test accuracy:', test_acc)
print('Validation accuracy:', validation_acc)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 256, 256, 64)      640
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 128, 128, 64)     0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)     73856
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)     147584
#
#  max_pooling2d_7 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 64, 64, 128)       0
#
#  batch_normalization_9 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 256)       295168
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 256)       590080
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  dropout_7 (Dropout)         (None, 32, 32, 256)       0
#
#  batch_normalization_10 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 512)      0
#  2D)
#
#  dropout_8 (Dropout)         (None, 16, 16, 512)       0
#
#  batch_normalization_11 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 131072)            0
#
#  dense_4 (Dense)             (None, 512)               67109376
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  batch_normalization_12 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_5 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 71,800,514
# Trainable params: 71,797,570
# Non-trainable params: 2,944
# _________________________________________________________________
# Epoch 1/20
# 311/311 [==============================] - 54s 152ms/step - loss: 0.5197 - accuracy: 0.8100 - val_loss: 0.3786 - val_accuracy: 0.8608
# Epoch 2/20
# 311/311 [==============================] - 45s 145ms/step - loss: 0.3948 - accuracy: 0.8588 - val_loss: 0.4386 - val_accuracy: 0.8690
# Epoch 3/20
# 311/311 [==============================] - 45s 145ms/step - loss: 0.3651 - accuracy: 0.8696 - val_loss: 0.3874 - val_accuracy: 0.8731
# Epoch 4/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.3323 - accuracy: 0.8799 - val_loss: 0.6516 - val_accuracy: 0.8499
# Epoch 5/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.3080 - accuracy: 0.8847 - val_loss: 0.3632 - val_accuracy: 0.8969
# Epoch 6/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2909 - accuracy: 0.8953 - val_loss: 0.4431 - val_accuracy: 0.8871
# Epoch 7/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2635 - accuracy: 0.9031 - val_loss: 0.3554 - val_accuracy: 0.8979
# Epoch 8/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2461 - accuracy: 0.9104 - val_loss: 0.4408 - val_accuracy: 0.8969
# Epoch 9/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2373 - accuracy: 0.9086 - val_loss: 0.4214 - val_accuracy: 0.9005
# Epoch 10/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2224 - accuracy: 0.9203 - val_loss: 0.3597 - val_accuracy: 0.8706
# Epoch 11/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.2022 - accuracy: 0.9236 - val_loss: 0.4400 - val_accuracy: 0.9072
# Epoch 12/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1824 - accuracy: 0.9322 - val_loss: 0.3889 - val_accuracy: 0.8958
# Epoch 13/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1779 - accuracy: 0.9328 - val_loss: 0.4350 - val_accuracy: 0.9067
# Epoch 14/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1628 - accuracy: 0.9405 - val_loss: 0.7366 - val_accuracy: 0.8917
# Epoch 15/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1381 - accuracy: 0.9492 - val_loss: 0.5016 - val_accuracy: 0.9134
# Epoch 16/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1363 - accuracy: 0.9507 - val_loss: 0.6661 - val_accuracy: 0.9097
# Epoch 17/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1203 - accuracy: 0.9567 - val_loss: 0.3892 - val_accuracy: 0.9041
# Epoch 18/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1161 - accuracy: 0.9580 - val_loss: 0.9382 - val_accuracy: 0.9061
# Epoch 19/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1046 - accuracy: 0.9632 - val_loss: 0.4071 - val_accuracy: 0.9206
# Epoch 20/20
# 311/311 [==============================] - 45s 144ms/step - loss: 0.1032 - accuracy: 0.9631 - val_loss: 0.5122 - val_accuracy: 0.9108
# 76/76 [==============================] - 5s 48ms/step - loss: 0.5707 - accuracy: 0.9043
# 61/61 [==============================] - 3s 48ms/step - loss: 0.5122 - accuracy: 0.9108
# Test accuracy: 0.9042509198188782
# Validation accuracy: 0.9107787609100342

# %% [markdown]
# This model consists of 14 layers. There are four 2D convolutional layers with with increasing filters (64, 128, 256, 512), each having a (3, 3) kernel size, 'relu' activation, and 'same' padding. four Max-pooling layers of pool size (2,2) are used in the layers. The model includes three dropout layers with a dropout rate of 0.5. One flatten is used to convert 2D features to 1D features.

# %% [markdown]
# The model is compiled with the 'RMSprop' optimizer and the 'sparse_categorical_crossentropy' loss function.The accuracy metric is used to evaluate the model's performance.the model is trained for 20 epochs with a batch size of 25. Here test accuracy is 90% and validation accuracy is 91% .

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')
plt.show()

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper right')
plt.show()

# %%
}
